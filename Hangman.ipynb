# %% [markdown]
# <a href="https://colab.research.google.com/github/DaichiSL/PythonExercises_1/blob/main/Hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Brad Daichi Suwaki Lopez 1729288

# %%
import random

# List of words for the game
word_list = ["Artificial", "Intelligence", "Class", "Python", "Student", "Teacher", "Code", "Program", "Exercise", "Hangmane"]

# Function to select a random word from the list
def choose_word():
    return random.choice(word_list)

# Function to display the current state of the word with underscores for unrevealed letters
def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

# Function to play the Hangman game
def play_hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts = 6

    print("Welcome to Hangman!")

    while True:
        print("\nWord:", display_word(word_to_guess, guessed_letters))
        print("Attempts left:", attempts)

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word_to_guess:
            print("Good guess!")
        else:
            print("Incorrect guess.")
            attempts -= 1

        if display_word(word_to_guess, guessed_letters) == word_to_guess:
            print("\nCongratulations! You guessed the word:", word_to_guess)
            break

        if attempts == 0:
            print("\nYou ran out of attempts. The word was:", word_to_guess)
            break

# Start the game
play_hangman()

import random

# List of words for the game
word_list = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "kiwi", "lemon"]

# Function to select a random word from the list
def choose_word():
    return random.choice(word_list)

# Function to display the current state of the word with underscores for unrevealed letters
def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

# Function to play the Hangman game
def play_hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts = 6

    print("Welcome to Hangman!")

    while True:
        print("\nWord:", display_word(word_to_guess, guessed_letters))
        print("Attempts left:", attempts)

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word_to_guess:
            print("Good guess!")
        else:
            print("Incorrect guess.")
            attempts -= 1

        if display_word(word_to_guess, guessed_letters) == word_to_guess:
            print("\nCongratulations! You guessed the word:", word_to_guess)
            break

        if attempts == 0:
            print("\nYou ran out of attempts. The word was:", word_to_guess)
            break

# Start the game
play_hangman()
# Out:
# Welcome to Hangman!
#
# Word: _______
# Attempts left: 6
# Guess a letter: a
# Incorrect guess.
#
# Word: _______
# Attempts left: 5
# Guess a letter: e
# Good guess!
#
# Word: ____e__
# Attempts left: 5
# Guess a letter: i
# Incorrect guess.
#
# Word: ____e__
# Attempts left: 4
# Guess a letter: o
# Incorrect guess.
#
# Word: ____e__
# Attempts left: 3
# Guess a letter: u
# Good guess!
#
# Word: __u_e__
# Attempts left: 3
# Guess a letter: t
# Good guess!
#
# Word: _tu_e_t
# Attempts left: 3
# Guess a letter: s
# Incorrect guess.
#
# Word: _tu_e_t
# Attempts left: 2
# Guess a letter: j
# Incorrect guess.
#
# Word: _tu_e_t
# Attempts left: 1
# Guess a letter: d
# Good guess!
#
# Word: _tude_t
# Attempts left: 1
# Guess a letter: n
# Good guess!
#
# Word: _tudent
# Attempts left: 1
# Guess a letter: tl
# Invalid input. Please enter a single letter.
#
# Word: _tudent
# Attempts left: 1
# Guess a letter: l
# Incorrect guess.
#
# You ran out of attempts. The word was: Student
# ...
