# %% [markdown]
# <a href="https://colab.research.google.com/github/DaichiSL/PythonExercises_1/blob/main/Hangman%20game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Brad Daichi Suwaki Lopez 1729288

# %%
import random

# List of words for the game
word_list = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "kiwi", "lemon"]

# Function to select a random word from the list
def choose_word():
    return random.choice(word_list)

# Function to display the current state of the word with underscores for unrevealed letters
def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

# Function to play the Hangman game
def play_hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts = 6

    print("Welcome to Hangman!")

    while True:
        print("\nWord:", display_word(word_to_guess, guessed_letters))
        print("Attempts left:", attempts)

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word_to_guess:
            print("Good guess!")
        else:
            print("Incorrect guess.")
            attempts -= 1

        if display_word(word_to_guess, guessed_letters) == word_to_guess:
            print("\nCongratulations! You guessed the word:", word_to_guess)
            break

        if attempts == 0:
            print("\nYou ran out of attempts. The word was:", word_to_guess)
            break

# Start the game
play_hangman()

import random

# List of words for the game
word_list = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew", "kiwi", "lemon"]

# Function to select a random word from the list
def choose_word():
    return random.choice(word_list)

# Function to display the current state of the word with underscores for unrevealed letters
def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

# Function to play the Hangman game
def play_hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts = 6

    print("Welcome to Hangman!")

    while True:
        print("\nWord:", display_word(word_to_guess, guessed_letters))
        print("Attempts left:", attempts)

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word_to_guess:
            print("Good guess!")
        else:
            print("Incorrect guess.")
            attempts -= 1

        if display_word(word_to_guess, guessed_letters) == word_to_guess:
            print("\nCongratulations! You guessed the word:", word_to_guess)
            break

        if attempts == 0:
            print("\nYou ran out of attempts. The word was:", word_to_guess)
            break

# Start the game
play_hangman()
# Out:
# Welcome to Hangman!
#
# Word: __________
# Attempts left: 6
# Guess a letter: a
# Incorrect guess.
#
# Word: __________
# Attempts left: 5
# Guess a letter: e
# Good guess!
#
# Word: e__e__e___
# Attempts left: 5
# Guess a letter: r
# Good guess!
#
# Word: e__er_err_
# Attempts left: 5
# Guess a letter: o
# Incorrect guess.
#
# Word: e__er_err_
# Attempts left: 4
# Guess a letter: s
# Incorrect guess.
#
# Word: e__er_err_
# Attempts left: 3
# Guess a letter: t
# Incorrect guess.
#
# Word: e__er_err_
# Attempts left: 2
# Guess a letter: m
# Incorrect guess.
#
# Word: e__er_err_
# Attempts left: 1
# Guess a letter: n
# Incorrect guess.
#
# You ran out of attempts. The word was: elderberry
# Welcome to Hangman!
#
# Word: _____
# Attempts left: 6
